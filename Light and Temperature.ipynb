# %% [markdown]
# # `Light and Temperature.ipynb`
# Functions to examine light and temperature outputs from
# actimeters.
#
# Author:
# – Jon Clucas, 2017 jon.clucas@childmind.org
#
# © 2017, Child Mind Institute, Apache v2.0 License

# %% [markdown]
# setup:

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from config.CMI_colors.color_cycle import CMI_color_palette
from datetime import datetime
from utilities.fetch_data  import df_devices
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['axes.prop_cycle'] = CMI_color_palette()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Light

# %%
# get data
ldf = df_devices(['ActiGraph wGT3X-BT', 'GENEActiv Original (pink)'],
      'light', datetime(2017, 4, 7, 9, 30), datetime(2017, 4, 7, 10))

# %%
plt.plot(ldf)
# Out:
# [<matplotlib.lines.Line2D at 0x7fb16292e940>,
#  <matplotlib.lines.Line2D at 0x7fb15d50f8d0>]

# %% [markdown]
# ## Temperature

# %%
# get data
tdf = df_devices(['GENEActiv Original (black)', 'Empatica E4'],
      'temperature', datetime(2017, 4, 5, 9), datetime(2017, 4, 5, 10))

# %%
plt.plot(tdf)
# Out:
# [<matplotlib.lines.Line2D at 0x7fb1bed5b8d0>,
#  <matplotlib.lines.Line2D at 0x7fb1a14dd8d0>]
